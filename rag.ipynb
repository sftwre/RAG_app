# %%
import os
import ray
import sys
from pathlib import Path
from bs4 import BeautifulSoup, NavigableString

# %%
import sys; sys.path.append("..")
import warnings; warnings.filterwarnings("ignore")
from dotenv import load_dotenv; load_dotenv()
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Ray setup

# %%
ray.init(runtime_env={
    "env_vars": {
        "OPENAI_API_BASE": os.environ["OPENAI_API_BASE"],
        "OPENAI_API_KEY": os.environ["OPENAI_API_KEY"], 
        "DB_CONNECTION_STRING": os.environ["DB_CONNECTION_STRING"],
    },
    "working_dir": './'
})
# Out:
# 2024-04-27 04:26:54,834	WARNING services.py:1996 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 66031616 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=0.53gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2024-04-27 04:26:56,007	INFO worker.py:1749 -- Started a local Ray instance.
# 2024-04-27 04:27:20,281	INFO packaging.py:530 -- Creating a file package for local directory './'.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/ray/_private/runtime_env/working_dir.py:85, in upload_working_dir_if_needed(runtime_env, scratch_dir, logger, upload_fn)
#      84 try:
# ---> 85     upload_package_if_needed(
#      86         working_dir_uri,
#      87         scratch_dir,
#      88         working_dir,
#      89         include_parent_dir=False,
#      90         excludes=excludes,
#      91         logger=logger,
#      92     )
#      93 except Exception as e:
#
# File /usr/local/lib/python3.10/site-packages/ray/_private/runtime_env/packaging.py:588, in upload_package_if_needed(pkg_uri, base_directory, directory, include_parent_dir, excludes, logger)
#     581 create_package(
#     582     directory,
#     583     package_file,
#     584     include_parent_dir=include_parent_dir,
#     585     excludes=excludes,
#     586 )
# --> 588 upload_package_to_gcs(pkg_uri, package_file.read_bytes())
#     590 # Remove the local file to avoid accumulating temporary zip files.
#
# File /usr/local/lib/python3.10/site-packages/ray/_private/runtime_env/packaging.py:507, in upload_package_to_gcs(pkg_uri, pkg_bytes)
#     506 if protocol == Protocol.GCS:
# --> 507     _store_package_in_gcs(pkg_uri, pkg_bytes)
#     508 elif protocol in Protocol.remote_protocols():
#
# File /usr/local/lib/python3.10/site-packages/ray/_private/runtime_env/packaging.py:349, in _store_package_in_gcs(pkg_uri, data, logger)
#     348 if len(data) >= GCS_STORAGE_MAX_SIZE:
# --> 349     raise ValueError(
#     350         f"Package size ({size_str}) exceeds the maximum size of "
#     351         f"{_mib_string(GCS_STORAGE_MAX_SIZE)}. You can exclude large "
#     352         "files using the 'excludes' option to the runtime_env or provide "
#     353         "a remote URI of a zip file using protocols such as 's3://', "
#     354         "'https://' and so on, refer to "
#     355         "https://docs.ray.io/en/latest/ray-core/handling-dependencies.html#api-reference."  # noqa
#     356     )
#     358 logger.info(f"Pushing file package '{pkg_uri}' ({size_str}) to Ray cluster...")
#
# ValueError: Package size (576.67MiB) exceeds the maximum size of 500.00MiB. You can exclude large files using the 'excludes' option to the runtime_env or provide a remote URI of a zip file using protocols such as 's3://', 'https://' and so on, refer to https://docs.ray.io/en/latest/ray-core/handling-dependencies.html#api-reference.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeEnvSetupError                      Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ray.init(runtime_env={
#       2     "env_vars": {
#       3         "OPENAI_API_BASE": os.environ["OPENAI_API_BASE"],
#       4         "OPENAI_API_KEY": os.environ["OPENAI_API_KEY"],
#       5         "DB_CONNECTION_STRING": os.environ["DB_CONNECTION_STRING"],
#       6     },
#       7     "working_dir": './'
#       8 })
#
# File /usr/local/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/ray/_private/worker.py:1751, in init(address, num_cpus, num_gpus, resources, labels, object_store_memory, local_mode, ignore_reinit_error, include_dashboard, dashboard_host, dashboard_port, job_config, configure_logging, logging_level, logging_format, log_to_driver, namespace, runtime_env, storage, **kwargs)
#    1748 else:
#    1749     logger.info(info_str)
# -> 1751 connect(
#    1752     _global_node,
#    1753     _global_node.session_name,
#    1754     mode=driver_mode,
#    1755     log_to_driver=log_to_driver,
#    1756     worker=global_worker,
#    1757     driver_object_store_memory=_driver_object_store_memory,
#    1758     job_id=None,
#    1759     namespace=namespace,
#    1760     job_config=job_config,
#    1761     entrypoint=ray._private.utils.get_entrypoint_name(),
#    1762 )
#    1763 if job_config and job_config.code_search_path:
#    1764     global_worker.set_load_code_from_local(True)
#
# File /usr/local/lib/python3.10/site-packages/ray/_private/worker.py:2318, in connect(node, session_name, mode, log_to_driver, worker, driver_object_store_memory, job_id, namespace, job_config, runtime_env_hash, startup_token, ray_debugger_external, entrypoint, worker_launch_time_ms, worker_launched_time_ms)
#    2314 runtime_env = job_config.runtime_env or {}
#    2315 runtime_env = upload_py_modules_if_needed(
#    2316     runtime_env, scratch_dir, logger=logger
#    2317 )
# -> 2318 runtime_env = upload_working_dir_if_needed(
#    2319     runtime_env, scratch_dir, logger=logger
#    2320 )
#    2321 runtime_env = upload_worker_process_setup_hook_if_needed(
#    2322     runtime_env,
#    2323     worker,
#    2324 )
#    2325 # Remove excludes, it isn't relevant after the upload step.
#
# File /usr/local/lib/python3.10/site-packages/ray/_private/runtime_env/working_dir.py:94, in upload_working_dir_if_needed(runtime_env, scratch_dir, logger, upload_fn)
#      85         upload_package_if_needed(
#      86             working_dir_uri,
#      87             scratch_dir,
#    (...)
#      91             logger=logger,
#      92         )
#      93     except Exception as e:
# ---> 94         raise RuntimeEnvSetupError(
#      95             f"Failed to upload working_dir {working_dir} to the Ray cluster: {e}"
#      96         ) from e
#      97 else:
#      98     upload_fn(working_dir, excludes=excludes)
#
# RuntimeEnvSetupError: Failed to set up runtime environment.
# Failed to upload working_dir ./ to the Ray cluster: Package size (576.67MiB) exceeds the maximum size of 500.00MiB. You can exclude large files using the 'excludes' option to the runtime_env or provide a remote URI of a zip file using protocols such as 's3://', 'https://' and so on, refer to https://docs.ray.io/en/latest/ray-core/handling-dependencies.html#api-reference.

# %% [markdown]
# # Build Ray Materialized Dataset

# %%
EFS_DIR = './docs'
DOCS_DIR = Path(EFS_DIR, 'docs.ray.io/en/master/')

ds = ray.data.from_items([{'path': path} for path in DOCS_DIR.rglob('*.html') if not path.is_dir()])

print(f"{ds.count()} documents")
# Out:
# 2024-04-15 18:58:58,166	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 3042 documents
# (raylet) [2024-04-16 02:37:13,337 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12458246144; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:37:34,306 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12503347200; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:37:44,362 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12456562688; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:37:54,436 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12456546304; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:39:34,738 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12442918912; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:39:44,798 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12442832896; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:39:54,869 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12442710016; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:43:13,685 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12444688384; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:43:23,746 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12444590080; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:43:33,812 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12462395392; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:44:34,982 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12461223936; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:44:45,047 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12461240320; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:46:21,025 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12458524672; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:46:31,090 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12463783936; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:47:09,156 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12463521792; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:47:19,221 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12463497216; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:47:29,284 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12463542272; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:47:39,350 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12463562752; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:47:59,267 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12462329856; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:48:09,328 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12462100480; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:48:19,405 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12462084096; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02:48:29,473 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 12461998080; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 02
E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 4841574400; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 17:34:42,667 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 4780253184; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 17:34:52,717 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 4289064960; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 17:35:02,769 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3757350912; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 17:35:12,829 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3432857600; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 17:35:22,889 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3473100800; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 17:35:32,943 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3006734336; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 17:35:43,031 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 2857578496; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 17:35:53,088 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 2534756352; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 17:36:03,172 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 2193502208; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-16 17:36:13,227 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 1936875520; capacity: 250790436864. Object creation will fail if spilling is required.
# ...
# (raylet) [2024-04-17 05:45:24,128 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3695910912; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:45:34,174 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3695710208; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:45:44,219 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3694424064; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:45:54,277 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3702546432; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:46:04,339 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3693051904; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:46:14,391 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3702038528; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:46:24,447 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3701952512; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:46:34,510 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3695136768; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:46:44,562 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 4764430336; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:46:54,622 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5139304448; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:47:04,668 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5138149376; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:47:14,722 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5138006016; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:47:24,784 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5137686528; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:47:34,850 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5306032128; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:47:44,900 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5305651200; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:47:54,956 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5882970112; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:48:05,005 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5883785216; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:48:15,054 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5879336960; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:48:25,109 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5882097664; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:48:35,162 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5976559616; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:48:45,202 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 6024192000; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:48:55,244 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5667975168; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:49:05,302 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 6015242240; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:49:15,343 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 6016118784; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:49:25,392 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5620396032; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:49:35,452 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5958615040; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:49:45,507 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 6007222272; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:49:55,554 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 6002450432; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:50:05,593 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5995008000; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:50:15,642 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5955633152; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:50:25,701 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5869453312; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:50:35,756 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 6439751680; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:50:45,814 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 6203310080; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:50:55,889 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 6016598016; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:51:05,950 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 6690312192; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:51:16,004 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5619761152; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:51:26,057 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 4560691200; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:51:36,114 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3478609920; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:51:46,169 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 2404143104; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:51:56,227 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 2403659776; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:52:06,280 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 2404073472; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:52:16,336 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3476107264; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:52:26,394 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3475779584; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:52:36,469 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3482525696; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:52:46,550 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3482468352; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:52:56,633 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3482378240; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:53:06,712 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3474771968; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:53:16,779 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3474706432; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:53:26,852 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3474391040; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:53:36,925 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3474108416; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:53:46,993 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3473973248; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:53:57,067 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3473924096; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:54:07,134 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3473858560; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:54:17,208 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3473743872; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:54:27,284 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3487657984; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:54:37,355 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3480178688; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:54:47,416 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3476058112; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:54:57,497 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3475591168; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:55:07,574 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 3468173312; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:55:17,609 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 5458534400; capacity: 250790436864. Object creation will fail if spilling is required.
# (raylet) [2024-04-17 05:55:27,680 E 9002 38730532] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-04-15_18-58-53_847573_64993 is over 95% full, available space: 10841853952; capacity: 250790436864. Object creation will fail if spilling is required.

# %% [markdown]
# # Data extraction

# %%
def extract_text_from_section(section):
    texts = []
    for elem in section.children:
        if isinstance(elem, NavigableString):
            if elem.strip():
                texts.append(elem.strip())
        elif elem.name == "section":
            continue
        else:
            texts.append(elem.get_text().strip())
    return "\n".join(texts)

def extract_sections(record):
    with open(record["path"], "r", encoding="utf-8") as html_file:
        soup = BeautifulSoup(html_file, "html.parser")
    sections = soup.find_all("section")
    section_list = []
    for section in sections:
        section_id = section.get("id")
        section_text = extract_text_from_section(section)
        if section_id:
            uri = path_to_uri(path=record["path"])
            section_list.append({"source": f"{uri}#{section_id}", "text": section_text})
    return section_list

def path_to_uri(path, scheme="https://", domain="docs.ray.io"):
    return scheme + domain + str(path).split(domain)[-1]

# %%
sections_ds = ds.flat_map(extract_sections)
sections = sections_ds.take_all()
print (len(sections))
# Out:
# 2024-04-15 19:19:37,023	INFO streaming_executor.py:115 -- Starting execution of Dataset. Full log is in /tmp/ray/session_2024-04-15_18-58-53_847573_64993/logs/ray-data.log
# 2024-04-15 19:19:37,025	INFO streaming_executor.py:116 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[FlatMap(extract_sections)]
# 5654

# %%
from langchain.document_loaders import ReadTheDocsLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

chunk_size = 300
chunk_overlap = 50
text_splitter = RecursiveCharacterTextSplitter(
    separators=["\n\n", "\n", " ", ""],
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    length_function=len
)

# chunk a sample section
sample_section = sections_ds.take(1)[0]
chunks = text_splitter.create_documents(texts=[sample_section["text"]],
                                        metadatas=[{"source": sample_section["source"]}])
# Out:
# 2024-04-15 21:31:24,365	INFO streaming_executor.py:115 -- Starting execution of Dataset. Full log is in /tmp/ray/session_2024-04-15_18-58-53_847573_64993/logs/ray-data.log
# 2024-04-15 21:31:24,367	INFO streaming_executor.py:116 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[FlatMap(extract_sections)] -> LimitOperator[limit=1]

# %%
from functools import partial

def chunk_section(section, chunk_size, chunk_overlap):
    text_splitter = RecursiveCharacterTextSplitter(
        separators=["\n\n", "\n", " ", ""],
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len
    )
    chunks = text_splitter.create_documents(
        texts=[section["text"]],
        metadatas=[{"source": section["source"]}]
    )
    return [{"text": chunk.page_content, "source": chunk.metadata["source"]} for chunk in chunks]

# scale chunking
chunks_ds = sections_ds.flat_map(partial(
    chunk_section,
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap
))

print(f"{chunks_ds.count()} chunks")
chunks_ds.show(1)
# Out:
# 2024-04-15 22:18:17,095	INFO streaming_executor.py:115 -- Starting execution of Dataset. Full log is in /tmp/ray/session_2024-04-15_18-58-53_847573_64993/logs/ray-data.log
# 2024-04-15 22:18:17,096	INFO streaming_executor.py:116 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[FlatMap(extract_sections)->FlatMap(partial)] -> LimitOperator[limit=1]
# 3042 chunks
# {'text': 'Quickstart using the Ray Jobs CLI#\nThis guide walks through the Ray Jobs CLI commands available for submitting and interacting with a Ray Job.\nTo use the Jobs API programmatically with a Python SDK instead of a CLI, see Python SDK Overview.', 'source': 'https://docs.ray.io/en/master/cluster/running-applications/job-submission/quickstart.html#quickstart-using-the-ray-jobs-cli'}

# %%
import numpy as np
from ray.data import ActorPoolStrategy
from langchain.embeddings import OpenAIEmbeddings
from langchain.embeddings.huggingface import HuggingFaceBgeEmbeddings

class EmbedChunks:
    def __init__(self, model_name) -> None:
        if model_name == 'text-embedding-ada-002':
            self.embedding_model = OpenAIEmbeddings(
                model=model_name,
                openai_api_base=os.environ['OPENAI_API_BASE'],
                openai_api_key=os.environ['OPENAI_API_KEY']
            )
        else:
            self.embedding_model = HuggingFaceBgeEmbeddings(
                model_name=model_name,
                model_kwargs={'device': 'cpu'},
                encode_kwargs={'device': 'cpu', 'batch_size': 100}
            )
    def __call__(self, batch):
        embeddings = self.embedding_model.embed_documents(batch['text'])
        return {'text': batch['text'], 'source': batch['source'], 'embeddings': embeddings}

# %%
# embed chunks
embedding_model_name = 'thenlper/gte-base'
embedded_chunks = chunks_ds.map_batches(
    EmbedChunks,
    fn_constructor_kwargs={'model_name': embedding_model_name},
    batch_size=100,
    concurrency=2
)

# %%
class StoreResults:
    def __call__(self, batch):
        with psycopg.connect(os.environ['DB_CONNECTION_STRING']) as conn:
            register_vector(conn)
            with conn.cursor() as cur:
                for text, source, embedding in zip (batch['text'], batch['source'], batch['embeddings']):
                    cur.execute("INSERT INTO document (text, source, embedding)")
